# %%
class X:
    def do(self):
        self.test= 1
        print("Do")
        print(vars(self).items())

# %%
x = X()
x.do()
# Out:
# Do
# dict_items([('test', 1)])

# %%
x = [1, 1, 1, 1]

# %%
x[1::1]
# Out:
# [1, 1, 1]
